# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\romai\Downloads\vecto\2020_05_18-VECTO-3.3.7.1964\Mission Profiles\Urban.vdri")
df[:500].plot(y="<v>", x="<s>", figsize=(15, 5))
# Out:
# <AxesSubplot:xlabel='<s>'>

# %%
df = pd.read_csv(r"C:\Users\romai\Downloads\vecto\2020_05_18-VECTO-3.3.7.1964\Mission Profiles\HeavyUrban.vdri")
df.plot(y="<v>", figsize=(15, 5))
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv(r"C:\Users\romai\Downloads\vecto\2020_05_18-VECTO-3.3.7.1964\Mission Profiles\Interurban.vdri")
df[["<s>", "<v>"]].plot(y="<v>", figsize=(15, 5))
# Out:
# <AxesSubplot:>

# %%
df.tail()
# Out:
#          <s>  <v>    <grad>  <stop>
# 6108  275019   74 -1.314889       0
# 6109  275039   74 -1.204229       0
# 6110  275059   74 -1.093569       0
# 6111  275079   74 -0.968545       0
# 6112  275176    0 -0.968545       2

# %%
df = pd.read_csv(r"C:\Users\romai\Downloads\vecto\2020_05_18-VECTO-3.3.7.1964\Mission Profiles\Coach.vdri")
df[["<s>", "<v>"]].plot(y="<v>", x="<s>", figsize=(15, 5))
# Out:
# <AxesSubplot:xlabel='<s>'>

# %%
df = pd.read_csv(r"C:\Users\romai\Downloads\vecto\2020_05_18-VECTO-3.3.7.1964\Mission Profiles\Suburban.vdri")
df[["<s>", "<v>"]].plot(y="<v>", figsize=(15, 5))
# Out:
# <AxesSubplot:>
